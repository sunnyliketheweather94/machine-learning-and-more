# %%
from loguru import logger
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import pymc as pm
import arviz as az

# %%
try:
    data = pl.read_csv("exercise_21.csv")
except Exception as e:
    logger.error(e)
    data = pd.read_stata("exercise_21.dta")
    data = pl.DataFrame(data[["state", "party4"]])
    data.write_csv("exercise_21.csv")

data.head()
# Out:
# shape: (5, 2)
# ┌───────────────┬─────────────┐
# │ state         ┆ party4      │
# │ ---           ┆ ---         │
# │ str           ┆ str         │
# ╞═══════════════╪═════════════╡
# │ massachusetts ┆ democrat    │
# │ massachusetts ┆ republican  │
# │ massachusetts ┆ independent │
# │ massachusetts ┆ independent │
# │ massachusetts ┆ democrat    │
# └───────────────┴─────────────┘

# %%
data = (
    data.group_by(["state", "party4"])
    .len()
    .pivot("party4", index="state", values="len", aggregate_function="sum")
    .fill_null(0)
    .with_columns((pl.col("independent") + pl.col("null")).alias("other"))
    .drop("null")
    .with_columns(
        (
            pl.col(r"other\no preference\dk\refused")
            + pl.col("republican")
            + pl.col("democrat")
            + pl.col("independent")
        ).alias("total")
    )
    .filter(~pl.col("state").is_in(["alaska", "hawaii", "washington dc"]))
)

data.head()
# Out:
# shape: (5, 7)
# ┌──────────┬──────────┬────────────────────────────────┬────────────┬─────────────┬───────┬───────┐
# │ state    ┆ democrat ┆ other\no preference\dk\refused ┆ republican ┆ independent ┆ other ┆ total │
# │ ---      ┆ ---      ┆ ---                            ┆ ---        ┆ ---         ┆ ---   ┆ ---   │
# │ str      ┆ u32      ┆ u32                            ┆ u32        ┆ u32         ┆ u32   ┆ u32   │
# ╞══════════╪══════════╪════════════════════════════════╪════════════╪═════════════╪═══════╪═══════╡
# │ colorado ┆ 156      ┆ 23                             ┆ 155        ┆ 131         ┆ 134   ┆ 465   │
# │ kansas   ┆ 98       ┆ 11                             ┆ 97         ┆ 119         ┆ 123   ┆ 325   │
# │ new york ┆ 705      ┆ 111                            ┆ 354        ┆ 496         ┆ 531   ┆ 1666  │
# │ vermont  ┆ 25       ┆ 5                              ┆ 25         ┆ 59          ┆ 60    ┆ 114   │
# │ florida  ┆ 564      ┆ 85                             ┆ 585        ┆ 483         ┆ 513   ┆ 1717  │
# └──────────┴──────────┴────────────────────────────────┴────────────┴─────────────┴───────┴───────┘

# %% [markdown]
# **Model:**
# - let $n_j$ be the survey sample size in state $j$
# - let $y_j$ be the number of people identifying as democrats in state $j$
# - let $\theta_j$ be the proportion of democrats in state $j$
# - then we have:
# $$
# \begin{align}
# \alpha & \sim \text{HalfNormal}(6) \\
# \beta & \sim \text{HalfNormal}(10) \\
# \theta_j & \sim \text{Beta}(\alpha, \beta) \\
# y_j & \sim \text{Binomial} ( n_j , \theta_j )
# \end{align}
# $$
# where $\alpha$ and $\beta$ are the hyperpriors

# %%
coords = {"states": data["state"].to_list()}

with pm.Model(coords=coords) as model:
    alpha = pm.HalfNormal("alpha", sigma=10.0)
    beta = pm.HalfNormal("beta", sigma=12.0)
    theta = pm.Beta("theta", alpha=alpha, beta=beta, dims="states")

    democrats = pm.Binomial(
        "democrats",
        n=data["total"].to_list(),
        p=theta,
        dims="states",
        observed=data["democrat"].to_list(),
    )

    trace = pm.sample(2000, tune=1000)
    prior = pm.sample_prior_predictive(500)
    posterior = pm.sample_posterior_predictive(trace)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, theta]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 5 seconds.
# Sampling: [alpha, beta, democrats, theta]
# Sampling: [democrats]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.summary(trace)
# Out:
#                          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# alpha                  12.459  2.439   7.909   17.019      0.038    0.026
# beta                   25.915  5.014  16.712   35.364      0.076    0.054
# theta[colorado]         0.335  0.021   0.297    0.374      0.000    0.000
# theta[kansas]           0.304  0.024   0.257    0.346      0.000    0.000
# theta[new york]         0.421  0.012   0.399    0.443      0.000    0.000
# theta[vermont]          0.245  0.035   0.183    0.312      0.000    0.000
# theta[florida]          0.329  0.011   0.308    0.349      0.000    0.000
# theta[delaware]         0.339  0.038   0.272    0.414      0.000    0.000
# theta[maryland]         0.452  0.020   0.414    0.488      0.000    0.000
# theta[georgia]          0.342  0.015   0.314    0.370      0.000    0.000
# theta[minnesota]        0.336  0.017   0.303    0.367      0.000    0.000
# theta[new jersey]       0.320  0.015   0.289    0.348      0.000    0.000
# theta[nevada]           0.305  0.030   0.251    0.364      0.000    0.000
# theta[california]       0.383  0.009   0.366    0.400      0.000    0.000
# theta[rhode island]     0.228  0.033   0.166    0.288      0.000    0.000
# theta[new mexico]       0.388  0.031   0.331    0.447      0.000    0.000
# theta[indiana]          0.299  0.016   0.270    0.328      0.000    0.000
# theta[ohio]             0.350  0.013   0.327    0.373      0.000    0.000
# theta[tennessee]        0.289  0.016   0.260    0.321      0.000    0.000
# theta[south carolina]   0.256  0.020   0.219    0.293      0.000    0.000
# theta[iowa]             0.289  0.021   0.250    0.328      0.000    0.000
# theta[pennsylvania]     0.422  0.012   0.398    0.445      0.000    0.000
# theta[texas]            0.313  0.011   0.293    0.332      0.000    0.000
# theta[montana]          0.255  0.038   0.182    0.327      0.000    0.000
# theta[north dakota]     0.262  0.035   0.198    0.329      0.000    0.000
# theta[connecticut]      0.399  0.024   0.354    0.443      0.000    0.000
# theta[michigan]         0.390  0.015   0.361    0.418      0.000    0.000
# theta[north carolina]   0.360  0.015   0.332    0.387      0.000    0.000
# theta[utah]             0.198  0.023   0.155    0.240      0.000    0.000
# theta[oklahoma]         0.369  0.023   0.327    0.412      0.000    0.000
# theta[maine]            0.372  0.035   0.305    0.437      0.000    0.000
# theta[washington]       0.306  0.017   0.274    0.338      0.000    0.000
# theta[arkansas]         0.288  0.025   0.241    0.334      0.000    0.000
# theta[new hampshire]    0.239  0.030   0.182    0.296      0.000    0.000
# theta[virginia]         0.304  0.015   0.276    0.333      0.000    0.000
# theta[illinois]         0.398  0.014   0.371    0.425      0.000    0.000
# theta[missouri]         0.296  0.016   0.266    0.326      0.000    0.000
# theta[idaho]            0.233  0.032   0.171    0.292      0.000    0.000
# theta[mississippi]      0.345  0.027   0.296    0.398      0.000    0.000
# theta[alabama]          0.286  0.018   0.254    0.322      0.000    0.000
# theta[oregon]           0.393  0.022   0.354    0.435      0.000    0.000
# theta[arizona]          0.271  0.018   0.236    0.303      0.000    0.000
# theta[wisconsin]        0.317  0.017   0.285    0.347      0.000    0.000
# theta[kentucky]         0.421  0.021   0.381    0.460      0.000    0.000
# theta[wyoming]          0.213  0.051   0.118    0.311      0.001    0.001
# theta[massachusetts]    0.348  0.018   0.315    0.382      0.000    0.000
# theta[west virginia]    0.450  0.029   0.397    0.506      0.000    0.000
# theta[nebraska]         0.254  0.028   0.203    0.307      0.000    0.000
# theta[louisiana]        0.322  0.019   0.287    0.357      0.000    0.000
# theta[south dakota]     0.293  0.039   0.219    0.365      0.000    0.000
#
#                        ess_bulk  ess_tail  r_hat
# alpha                    4099.0    4030.0    1.0
# beta                     4302.0    4411.0    1.0
# theta[colorado]         11380.0    6437.0    1.0
# theta[kansas]           10012.0    5493.0    1.0
# theta[new york]         10166.0    5891.0    1.0
# theta[vermont]           9220.0    5791.0    1.0
# theta[florida]          11068.0    6513.0    1.0
# theta[delaware]         10803.0    6152.0    1.0
# theta[maryland]         12846.0    5800.0    1.0
# theta[georgia]          12199.0    5884.0    1.0
# theta[minnesota]        11364.0    5279.0    1.0
# theta[new jersey]       13869.0    6027.0    1.0
# theta[nevada]           12159.0    5672.0    1.0
# theta[california]       10454.0    5877.0    1.0
# theta[rhode island]     10455.0    5645.0    1.0
# theta[new mexico]       13566.0    6045.0    1.0
# theta[indiana]          11401.0    4809.0    1.0
# theta[ohio]             12135.0    5790.0    1.0
# theta[tennessee]        10849.0    5503.0    1.0
# theta[south carolina]   11818.0    6047.0    1.0
# theta[iowa]              9836.0    5345.0    1.0
# theta[pennsylvania]     12105.0    6074.0    1.0
# theta[texas]            12513.0    5741.0    1.0
# theta[montana]          10747.0    6219.0    1.0
# theta[north dakota]     12902.0    5642.0    1.0
# theta[connecticut]      12343.0    5768.0    1.0
# theta[michigan]          9842.0    5747.0    1.0
# theta[north carolina]   11917.0    6372.0    1.0
# theta[utah]             12374.0    6176.0    1.0
# theta[oklahoma]         12290.0    6016.0    1.0
# theta[maine]            11171.0    6135.0    1.0
# theta[washington]       12314.0    5903.0    1.0
# theta[arkansas]         13058.0    5486.0    1.0
# theta[new hampshire]    11334.0    5852.0    1.0
# theta[virginia]          9745.0    5649.0    1.0
# theta[illinois]         11907.0    5917.0    1.0
# theta[missouri]          9906.0    6017.0    1.0
# theta[idaho]             9385.0    5483.0    1.0
# theta[mississippi]      12408.0    5616.0    1.0
# theta[alabama]          12619.0    6017.0    1.0
# theta[oregon]           15005.0    6171.0    1.0
# theta[arizona]          12781.0    5757.0    1.0
# theta[wisconsin]        11625.0    5916.0    1.0
# theta[kentucky]         10573.0    5965.0    1.0
# theta[wyoming]           7700.0    5404.0    1.0
# theta[massachusetts]    11914.0    5928.0    1.0
# theta[west virginia]     9856.0    5750.0    1.0
# theta[nebraska]         11422.0    6134.0    1.0
# theta[louisiana]        11774.0    5937.0    1.0
# theta[south dakota]     11956.0    5951.0    1.0

# %%
az.plot_forest(trace, var_names="theta", combined=True)
plt.tight_layout()
plt.show()

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.hist(prior.prior["theta"].loc[:, :, "illinois"].mean("chain"))
ax2.hist(trace.posterior["theta"].loc[:, :, "illinois"].mean("chain"))

ax1.set_title(r"Prior distribution of $\theta_{\text{Illinois}}$")
ax2.set_title(r"Posterior distribution of $\theta_{\text{Illinois}}$")
plt.show()

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.hist(
    prior.prior_predictive["democrats"].loc[:, :, "illinois"].mean("chain"),
    density=True,
)

ax2.hist(
    posterior.posterior_predictive["democrats"].loc[:, :, "illinois"].mean("chain"),
    density=True,
)

plt.show()
